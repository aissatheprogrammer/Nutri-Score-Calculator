# %%
def scorer():
    

    

    # neg = numbes that need to be subtracted
    # pos = numbers that need to be added
    neg = 0
    pos = 0
    
    
    energy_kj_100g = float(input('enter the kj_100g: '))
    if energy_kj_100g <= 335:
        neg += 0
    elif energy_kj_100g >= 335 and energy_kj_100g < 670:
        neg += 1           
    elif energy_kj_100g >= 670 and energy_kj_100g < 1005:
        neg += 2
    elif energy_kj_100g >= 1005 and energy_kj_100g < 1340:
        neg += 3
    elif energy_kj_100g >= 1340 and energy_kj_100g < 1675:
        neg += 4
    elif energy_kj_100g >= 1675 and energy_kj_100g < 2010:
        neg += 5
    elif energy_kj_100g >= 2010 and energy_kj_100g < 2345:
        neg += 6
    elif energy_kj_100g >= 2345 and energy_kj_100g < 2680:
        neg += 7
    elif energy_kj_100g >= 2680 and energy_kj_100g < 3015:
        neg += 8
    elif energy_kj_100g >= 3015 and energy_kj_100g < 3350:
        neg += 9
    elif energy_kj_100g >= 3350:
        neg += 10
    else:
        print('kj err')


    sugars_100g = float(input('enter the sugars_100g: '))
    if sugars_100g <= 4.5:
        neg += 0
    elif sugars_100g >= 4.5 and sugars_100g < 9:
        neg += 1           
    elif sugars_100g >= 9 and sugars_100g < 13.5:
        neg += 2
    elif sugars_100g >= 13.5 and sugars_100g < 18:
        neg += 3
    elif sugars_100g >= 18 and sugars_100g < 22.5:
        neg += 4         
    elif sugars_100g >= 22.5 and sugars_100g < 27:
        neg += 5
    elif sugars_100g >= 27 and sugars_100g < 31:
        neg += 6
    elif sugars_100g >= 31 and sugars_100g < 36:
        neg += 7           
    elif sugars_100g >= 36 and sugars_100g < 40:
        neg += 8
    elif sugars_100g >= 40 and sugars_100g < 45:
        neg += 9
    elif sugars_100g >= 45:
        neg += 10          
    else:
        print('sugar err')


    saturated_fat_100g = float(input('enter the saturated-fat_100g: '))
    if saturated_fat_100g <= 1:
        neg += 0
    elif saturated_fat_100g >= 1 and saturated_fat_100g < 2:
        neg += 1           
    elif saturated_fat_100g >= 2 and saturated_fat_100g < 3:
        neg += 2
    elif saturated_fat_100g >= 3 and saturated_fat_100g < 4:
        neg += 3
    elif saturated_fat_100g >= 4 and saturated_fat_100g < 5:
        neg += 4
    elif saturated_fat_100g >= 5 and saturated_fat_100g < 6:
        neg += 5
    elif saturated_fat_100g >= 6 and saturated_fat_100g < 7:
        neg += 6
    elif saturated_fat_100g >= 7 and saturated_fat_100g < 8:
        neg += 7
    elif saturated_fat_100g >= 8 and saturated_fat_100g < 9:
        neg += 8
    elif saturated_fat_100g >= 9 and saturated_fat_100g < 10:
        neg += 9
    elif saturated_fat_100g >= 10:
        neg += 10
    else:
        print('fat err')
        

    sel = float(input('enter the sel: '))
    sodium_100g = sel * 400
    if sodium_100g <= 90:
        neg += 0
    elif sodium_100g >= 90 and sodium_100g < 180:
        neg += 1           
    elif sodium_100g >= 180 and sodium_100g < 270:
        neg += 2
    elif sodium_100g >= 270 and sodium_100g < 360:
        neg += 3
    elif sodium_100g >= 360 and sodium_100g < 450:
        neg += 4
    elif sodium_100g >= 450 and sodium_100g < 540:
        neg += 5
    elif sodium_100g >= 540 and sodium_100g < 630:
        neg += 6
    elif sodium_100g >= 630 and sodium_100g < 720:
        neg += 7
    elif sodium_100g >= 720 and sodium_100g < 810:
        neg += 8
    elif sodium_100g >= 810 and sodium_100g < 900:
        neg += 9
    elif sodium_100g >= 900:
        neg += 10
    else:
        print('sodium err')

    fruits_vegetable_percentage = float(input('enter the fruits_vegetable_percentage: '))
    if fruits_vegetable_percentage <= 40:
        pos += 0
    elif fruits_vegetable_percentage >= 40 and fruits_vegetable_percentage < 60:
        pos += 1           
    elif fruits_vegetable_percentage >= 60 and fruits_vegetable_percentage < 80:
        pos += 2
    elif fruits_vegetable_percentage >= 80:
        pos += 5
    else:
        print('fruits err')

        
    fiber_100g = float(input('enter the fiber_100g: '))
    if fiber_100g <= 0.9:
        pos += 0
    elif fiber_100g >= 0.9 and fiber_100g < 1.9:
        pos += 1           
    elif fiber_100g >= 1.9 and fiber_100g < 2.8:
        pos += 2
    elif fiber_100g >= 2.8 and fiber_100g < 3.7:
        pos += 3
    elif fiber_100g >= 3.7 and fiber_100g < 4.7:
        pos += 4  
    elif fiber_100g >= 4.7:
        pos += 5
    else:
        print('fiber err')

    proteins_100g = float(input('enter the proteins_100g: '))
    if proteins_100g <= 1.6 :
        pos += 0
    elif proteins_100g >= 1.6 and proteins_100g < 3.2:
        pos += 1           
    elif proteins_100g >= 3.2 and proteins_100g < 4.8:
        pos += 2
    elif proteins_100g >= 4.8 and proteins_100g < 6.4:
        pos += 3
    elif proteins_100g >= 6.4 and proteins_100g < 8:
        pos += 4  
    elif proteins_100g >= 8:
        pos += 5
    else:
        print('prot err')


    num_score = neg - pos
    if num_score >= -15 and num_score <= -1:
        nutriscore = 'a'
    elif num_score >= 0 and num_score <= 2:
        nutriscore = 'b'        
    elif num_score >= 3 and num_score <= 10:
        nutriscore = 'c'
    elif num_score >= 11 and num_score <= 18:
        nutriscore = 'd'
    elif num_score >= 19 and num_score <= 40:
        nutriscore = 'e'  
    else:
        print('letter err')
    return nutriscore

scorer()
